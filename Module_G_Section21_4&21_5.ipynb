# %% [markdown]
# <a href="https://colab.research.google.com/github/SimonT2003/MAT421/blob/main/Module_G_Section21_4%2621_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simpson's Rule in Python

# %% [markdown]
# Simpson's Rule - approximates the area under f(x) over two subintervals of $[x_i−1,x_i]$ and $[x_i,x_i+1]$ by fitting a quadratic polynomial through the points $(x_i−1,f(x_i−1)),(x_i,f(x_i))$, and $(x_i+1,f(x_i+1))$, which is a unique polynomial, and then integrating the quadratic exactly.

# %%
#Use Simpson’s Rule to approximate ∫[π, 0] cox(x)dx with 15 evenly spaced grid points over the whole interval.
#Compare this value to the exact value of 2
import numpy as np

a = 0
b = np.pi
n = 15
h = (b - a) / (n - 1)
x = np.linspace(a, b, n)
f = np.cos(x)

I_simp = (h/3) * (f[0] + 2*sum(f[:n-2:2]) \
            + 4*sum(f[1:n-1:2]) + f[n-1])
err_simp = 2 - I_simp

print(I_simp)
print(err_simp)
# Out:
# 0.14959965017094254
# 1.8504003498290575

# %% [markdown]
# # Computing Integrals in Python

# %%
#Use the trapz function to approximate ∫[π, 0] sin(x)dx for 11 equally spaced points over the whole interval.
#Compare this value to the one computed in the early example using the Trapezoid Rule.
import numpy as np
from scipy.integrate import trapz

a = 0
b = np.pi
n = 11
h = (b - a) / (n - 1)
x = np.linspace(a, b, n)
f = np.sin(x)

I_trapz = trapz(f,x)
I_trap = (h/2)*(f[0] + 2 * sum(f[1:n-1]) + f[n-1])

print(I_trapz)
print(I_trap)
# Out:
# 1.9835235375094544
# 1.9835235375094546

# %%
#Use the cumtrapz function to approximate the cumulative integral of f(x)=sin(x) from 0 to π with a discretization step of 0.01.
#The exact solution of this integral is F(x)=sin(x). Plot the results.

from scipy.integrate import cumtrapz
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use('seaborn-poster')

x = np.arange(0, np.pi, 0.01)
F_exact = -np.cos(x)
F_approx = cumtrapz(np.sin(x), x)

plt.figure(figsize = (10,6))
plt.plot(x, F_exact)
plt.plot(x[1::], F_approx)
plt.grid()
plt.tight_layout()
plt.title('The Integral of sin (y) dy from 0 to x')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend(['Exact with Offset', 'Approx'])
plt.show()
# Out:
# <ipython-input-6-416abd314c85>:8: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')

# %%
#Use the integrate.quad function to compute ∫π0sin(x)dx. Compare your answer with the correct answer of 2.
from scipy.integrate import quad

I_quad, est_err_quad = \
          quad(np.sin, 0, np.pi)
print(I_quad)
err_quad = 2 - I_quad
print(est_err_quad, err_quad)
# Out:
# 2.0
# 2.220446049250313e-14 0.0

# %% [markdown]
# ## End of Module G

# %% [markdown]
# ## Resource

# %% [markdown]
# https://github.com/Li0741/MAT421-SP23/blob/main/ModuleG_2.ipynb
