# %% [markdown]
# <a href="https://colab.research.google.com/github/SimonT2003/MAT421/blob/main/HW_Module_F_20_1_20_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module F - 20.1-20.4

# %% [markdown]
# ## 20.1 - Numerical Differentiation Problem Statement

# %% [markdown]
# A numerical grid is an evenly spaced set of points over the domain of a function over some interval.
#
# Spacing or step size of a numerical grid is the distance between adjacent points on the grid.

# %%
print(' x-2   x-1     x    x+1   x+2   x+3  ')
print('   |     |     |     |     |     |   ')
print('------------------------------------->x')
print('   |<-h->|<-h->|<-h->|<-h->|<-h->|')
# Out:
#  x-2   x-1     x    x+1   x+2   x+3
#    |     |     |     |     |     |
# ------------------------------------->x
#    |<-h->|<-h->|<-h->|<-h->|<-h->|

# %% [markdown]
# ## 20.2 - Finite Difference Approximating Derivatives

# %% [markdown]
# In finite difference approximations of this slope, we can use values of the function in the neighborhood of the point x=a to achieve the goal.
#
# Forward difference is to estimate the slope of the function at xj using the line that connects (x_j, f(x_j)) and (x_j+1, f(x_j+1))
#
# f'(x_j) = (f(x_j+1) - f(x_j)) / (x_j+1 - x_j)
#
# Backward difference is to estimate the slope of the function at xj using the line that connects (x_j−1,f(x_j−1)) and (xj,f(xj)):
#
# f'(x_j) = (f(x_j) - f(x_j-1)) / (x_j - x_j-1)
#
# Central difference is to estimate the slope of the function at xj using the line that connects (x_j−1, f(x_j−1)) and (x_j+1, f(x_j+1)):
#
# f'(x_j) = (f(x_j+1) - f(x_j-1)) / (x_j+1 - x_j-1)

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-poster')
# %matplotlib inline

# step size
h = 0.1
# define grid
x = np.arange(0, 2*np.pi, h)
# compute function
y = np.sin(x)

# compute vector of forward differences
forward_diff = np.diff(y)/h
# compute corresponding grid
x_diff = x[:-1:]
# compute exact solution
exact_solution = np.cos(x_diff)

# Plot solution
plt.figure(figsize = (12, 8))
plt.plot(x_diff, forward_diff, '--', \
         label = 'Finite difference approximation')
plt.plot(x_diff, exact_solution, \
         label = 'Exact solution')
plt.legend()
plt.show()

# Compute max error between
# numerical derivative and exact solution
max_error = max(abs(exact_solution - forward_diff))
print(max_error)
# Out:
# <ipython-input-2-55b43e11a833>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')
# 0.04997515074549317

# %% [markdown]
# ## 20.3 - Approximating of Higher Order Derivatives

# %% [markdown]
# Using Taylor Series to approximate higher order derivatives:
#
# f(x_j-1) + f(x_j+1) = 2*f(x_j) + (h^2)(f''(x_j)) + ((h^4)(f''''(x_j)))/24 + ...
#
# And this give the appromixation of O(h^2) = f''(x_j) = (f(x_j+1) - 2*f(x_j) + f(x_j-1))/(h^2)

# %% [markdown]
# ## 20.4 - Numerical Differentiation with Noise

# %% [markdown]
# Noise - when value is off by a small amount from what it would be if it were computed from a pure mathematical function

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-poster')
# %matplotlib inline

x = np.arange(0, 2*np.pi, 0.01)

omega = 110
epsilon = 0.1

y = np.sin(x)
y_noise = y + epsilon*np.cos(omega*x)

plt.figure(figsize = (12, 8))
plt.plot(x, y_noise, 'r-', label = 'sin(x) + noise')
plt.plot(x, y, 'b-', label = 'sin(x)')

plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# <ipython-input-3-38a7c3344176>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')

# %% [markdown]
# ## Resource

# %% [markdown]
# https://github.com/Li0741/MAT421-SP23/blob/main/ModuleF.ipynb

# %% [markdown]
# ## End
